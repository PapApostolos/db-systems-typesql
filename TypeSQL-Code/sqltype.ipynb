# %% [markdown]
# **Prerequisites**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install records==0.5.2
import time
import records
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Device's Information**

# %%
import torch
print(torch.__version__)
# Out:
# 1.6.0+cu101

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
'''
# !wget '/content/drive/My Drive/' http://nlp.stanford.edu/data/glove.42B.300d.zip
# !wget http://nlp.stanford.edu/data/glove.42B.300d.zip
# !unzip'content/glove.42B.300d.zip' -d '/content/drive/My Drive/Database Systems/'
'''
# Out:
# "\n!wget '/content/drive/My Drive/' http://nlp.stanford.edu/data/glove.42B.300d.zip\n!wget http://nlp.stanford.edu/data/glove.42B.300d.zip\n!unzip'content/glove.42B.300d.zip' -d '/content/drive/My Drive/Database Systems/'\n"

# %%
# %cd /content/gdrive/My Drive/Database Systems/TypeSQL
# Out:
# /content/gdrive/.shortcut-targets-by-id/1n8yraOxbJ7jAAg28YxcpXqo4Mk1OmyLR/Database Systems/TypeSQL

# %% [markdown]
# **Code**

# %% [markdown]
# **Training**

# %%
# !python MyTypeSQL.py
# Out:
# ['MyTypeSQL.py']
# 1.6.0+cu101
#
# --------  description  --------
#
# !python mytypesql.py: Description
#
# !python mytypesql.py arg1 arg2 ... arg6
# arg1: Folder=["Folder_For_Saving_Models"]
# arg2: content=[0 | 1]
# arg3: GPU=[True | False]
# arg4: Optimizer=[adam|sgd|adadelta]
# arg5: No units =[ 60 | 120 | 180 ]
# arg6: Testing=[ yes | no ]

# %%
# !python MyTypeSQL.py Sav_Models 1 True adam 120 yes
# Out:
# ['MyTypeSQL.py', 'Sav_Models', '1', 'True', 'adam', '120', 'yes']
# 1.6.0+cu101
#
# GPU Available: True
# Numbe-Of-Units: 120
# DB Content: Available
#
#
# Training $Slots_Models:
#     TRAIN_AGG= True
#     TRAIN_SEL= True
#     TRAIN_COND True
#
# Load data...
#     From data/train_tok.jsonl
#     From data/train_tok.tables.jsonl
#     From data/dev_tok.jsonl
#     From data/dev_tok.tables.jsonl
#     From data/test_tok.jsonl
#     From data/test_tok.tables.jsonl
#
# Sav_Models <class 'str'>
# Sav_Models/old_sqlnet.agg_model Sav_Models/old_sqlnet.sel_model Sav_Models/old_sqlnet.cond_model
# Sav_Models/old_sqlnet.agg_embed Sav_Models/old_sqlnet.sel_embed Sav_Models/old_sqlnet.cond_embed
# Location: Sav_Models
#      Sav_Models/old_sqlnet.agg_model Sav_Models/old_sqlnet.sel_model Sav_Models/old_sqlnet.cond_model
#      Sav_Models/old_sqlnet.agg_embed Sav_Models/old_sqlnet.sel_embed Sav_Models/old_sqlnet.cond_embed
#
# Embeddings
#     From glove/glove.6B.300d.txt  &
# ...

# %% [markdown]
# **Testing**

# %%
# !python Testing.py
# Out:
#  ----------------------------  Description  ----------------------------
#
#     Run: python Testing.py       # Default Model (Epochs:7, Units:180, Opt:Adam )
#     Run: python Testing.py Cont0 # If you have Already trained a model with Cont0
#     Run: python Testing.py Cont1 # If you have Already trained a model with Cont1
#
# Note: If you Test your Model (not Default) change the variables in this script manually
#
# Load data...
#     From data/train_tok.jsonl
#     From data/train_tok.tables.jsonl
#     From data/dev_tok.jsonl
#     From data/dev_tok.tables.jsonl
#     From data/test_tok.jsonl
#     From data/test_tok.tables.jsonl
#     Testing: DEFAULT MODEL
#
#
#
#
#  ----------------------------  Test Cont-0  ----------------------------
# Embeddings
#     From glove/glove.6B.300d.txt  &
#     From para-nmt-50m/data/paragram_sl999_czeng.txt
# N_h 180
#     Using trainable embedding
#     Using trainable embedding
#     Using trainable embedding
# ...
